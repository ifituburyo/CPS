# %% [markdown]
# ### 1. Autoencoder-Based Anomaly Detection (LSTM Autoencoder)

# %% [markdown]
# Train on normal segments (e.g., 0–6 hrs, 11–end).
#
# Reconstruct input using LSTM encoder-decoder.
#
# Compute reconstruction error at each time step.
#
# High error during 6–11 hrs = potential leak.

# %% [markdown]
# ### 2. Statistical Models (e.g., ARIMA, Moving Average Residuals)
# #### Why: If the signal is mostly smooth or seasonal, these models can detect deviations.
#
# ###### How it works:
#
# Fit ARIMA model on clean part.
#
# Forecast next steps.
#
# Compare forecast vs actual.
#
# Large residuals in leak window.

# %% [markdown]
# # Optimization in Distributed systems

# %% [markdown]
# 1. Decentralized Vs. Centralized Optmization

# %% [markdown]
# 2. Gradient Based Optmization

# %% [markdown]
# 3. Consensus-Based Methods

# %% [markdown]
# 4. Resource optmization

# %% [markdown]
# ## Popular Optmizer in Distributed Systems

# %% [markdown]
# 1. SDG

# %% [markdown]
# 2. Adam

# %% [markdown]
# 3. L-BFGS

# %% [markdown]
# 4. ADMM

# %% [markdown]
# 5. Federated Averaging

# %% [markdown]
# ## In system Optmization

# %% [markdown]
# 1. Greedy Algorithm

# %% [markdown]
# 2. MetaHeuristics (Genetic,Simulated Annealing, Particle Swarm Optimization, )

# %% [markdown]
# 3. Reinforcement  Learning

# %% [markdown]
# 4. Gradient Free Methods

# %% [markdown]
# ## State estimation in Real-Time data networks

# %% [markdown]
# ### Kalman Filters

# %% [markdown]
# 1. Standard
# 2. Extended Kalman
# 3. Unscented Kalman
# 4. Distributed Kalman

# %% [markdown]
# ## Consensus-Based Estimation

# %% [markdown]
# 1. Consensus + Innovations
# 2. Diffusion Strategies
# 3. ADMM-based Concensus

# %% [markdown]
# ## Particle Filters

# %% [markdown]
# ## Moving Horizon Estimation (MHE)

# %% [markdown]
# ## Graph signal Processing abd Belief Propagation

# %% [markdown]
# ### 1. Machine learning model for abnormally detection in  Hydraulic signal analysis.

# %% [markdown]
# #### -  Considering single feature, like velocity , flowrate, pressure ,..
# #### -  Consideration on Demand partern to different use case
# #### -  Using binary classication to classify the normal and anomalies signal
# #### -  evaluation of the signal given

# %% [markdown]
# ## partial labelling the Dataset

# %%
# Example: labeling 10-minute leak period from timestamp 400 to 460
df['label'] = 0  # 0 = no leak
df.loc[(df.index >= 400) & (df.index <= 460), 'label'] = 1  # 1 = leak
